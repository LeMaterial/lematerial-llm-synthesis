# %%
from datasets import load_dataset

# ponytail: split isn't registered in the dataset config yet, load the parquet directly
ds = load_dataset(
    "parquet",
    data_files="hf://datasets/LeMaterial/LeMat-Synth-Papers/superconductor_keywords_and_LLM/full-00000-of-00001.parquet",
    split="train",
)
df = ds.to_pandas()
df

# %%
df.columns

# %%
df[["text_paper", "text_si", "source", "pdf_extractor", "images"]].head()

# %%
print(df["text_paper"].iloc[0])
